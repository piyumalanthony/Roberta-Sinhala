# %%
# # !pip3 install pandas
# import torch, gc
# gc.collect()
# torch.cuda.empty_cache()

# %%
import pandas as pd

# %%
# cd /content/drive/My Drive/FYP/Sentiment Analysis/Implementation/Sentiment Analysis/Capsule/Dynamic _rounting_enhancement_Capsule_network

# %%
folder_path =  '/userdirs/piyumal/roberta_sinhala/news_source_data/'

news_source_data_path = folder_path + 'newssource2.csv'

# %%
news_source_data = pd.read_csv(news_source_data_path)
news_source_data = news_source_data.drop(columns=['Unnamed: 0'])
# gossipLanka_data = pd.read_csv(gossip_lanka_data_path)
# gossipLanka_data = gossipLanka_data.drop(columns=['Unnamed: 3'])

# all_data = pd.concat([lankadeepa_data,gossipLanka_data], ignore_index=True)
# all_data.shape
news_source_data.shape
# Out:
# (24094, 2)

# %%
news_source_data
# Out:
#                                                  comment  label
# 0      ත්‍රිකුණාමලයේ දී නැගෙනහිර ආරක්ෂක සේනා මූලස්ථාන...      0
# 1                     59 වන සේනාංකය අලුත් අවුරුද්ද සමරයි      0
# 2      නිවාඩු නොමැතිව සේවයට නොපැමිණ සිටින ත්‍රිවිධ හම...      0
# 3      මුලතිව් ආරක්ෂක සේනා මුලස්ථානයේ බදාදා දිනයන් හි...      0
# 4      බෝයගනේ විජයබාහු පාබල රෙජිමේන්තු මධ්‍යස්ථානයට ස...      0
# ...                                                  ...    ...
# 24089  සිංහල බෞද්ධ අන්තවාදීහු ක්‍රිස්තියානි පල්ලි දෙක...      8
# 24090  යුකේ‍්‍රන අර්බුදය මුල්කරගෙන ජපානයේ රාජ්‍ය තාන්...      8
# 24091  බංග්ලාදේශය: ශිෂ්‍යාවක් අමානුෂික ලෙස ඝාතනය කිරී...      8
# 24092  මර්කෙල් හා ට‍්‍රම්ප් වොෂින්ටනයේ දී අර්බුද ග‍්‍...      8
# 24093  එක්සත් ජනපද මාධ්‍ය යුකේ‍්‍රනය පිලිබඳ දුෂ්-ප‍්‍...      8
#
# [24094 rows x 2 columns]

# %%
comments = news_source_data["comment"].tolist()

# %%
comments
# Out:
# ['ත්\u200dරිකුණාමලයේ දී නැගෙනහිර ආරක්ෂක සේනා මූලස්ථානය අලුත් අවුරුදු සමරයි',
#  '59 වන සේනාංකය අලුත් අවුරුද්ද සමරයි',
#  'නිවාඩු නොමැතිව සේවයට නොපැමිණ සිටින ත්\u200dරිවිධ හමුදා සාමාජිකයින් සඳහා මසක පොදු සමා කාලයක් ප්\u200dරකාශයට පත් කෙරේ',
#  'මුලතිව් ආරක්ෂක සේනා මුලස්ථානයේ බදාදා දිනයන් හිදී අධ්\u200dයාපනික දේශන වැඩසටහන්',
#  'බෝයගනේ විජයබාහු පාබල රෙජිමේන්තු මධ්\u200dයස්ථානයට සපැමිණි යුද්ධ හමුදාධිපතිතුමන් මහත් හරසරින් පිළිගැනේ',
#  'ලිංගිකව සම්ප්\u200dරේෂණය වන රෝග පිළිබඳව 24 වන සේනාංකයේ භට පිරිස් දැනුවත් කෙරේ',
#  'යුද්ධ හමුදාවේ සියලුම ක්\u200dරීඩා තරු එක වහළක් යටදී හමුවේ',
#  'යාවත්කාලීණ : ආරක්\u200dෂක අංශ හා ආරක්\u200dෂිත නිවාසය තුළ සිටි ත්\u200dරස්තවාදීන් අතර ඇතිවු ගැටුමෙන් මියගිය සංඛ්\u200dයාව 15 දක්වා ඉහළ ගොස් ඇත',
#  'යුද්ධ හමුදා අන්තර් රෙජිමේන්තු ක්\u200dරිකට් තරඟාවලියේ අවසන් මහා තරඟයේදී ලුතිනන් අජන්ත මෙන්ඩිස් පැසසුමට ලක්වෙයි',
#  'මඩකලපුව ප්\u200dරදේශයේ දී පාසල් උපකරණ හා ත්\u200dයාග පාර්සල් බෙදාදෙයි',
#  'කිළිනොච්චි තොරතුරු තාක්ෂණ පාඨමාලාව නිමාවේ',
# ...

# %%
labels = news_source_data["label"]

# %%
labels = labels.to_list()

# %%
label_set = set(labels)
label_set
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 8}

# %%
# import numpy as np
# n_values = 4
# lables_encoded = np.eye(n_values)[labels]

# %%
# lables_encoded

# %%
# !pip install transformers

# %%
# !pip3 install sklearn

# %%
from transformers import DistilBertTokenizerFast, RobertaTokenizerFast, RobertaTokenizer
# tokenizer = RobertaTokenizer.from_pretrained('/userdirs/piyumal/bert/sinhalaBert', max_len=512)
tokenizer = RobertaTokenizer(vocab_file='/userdirs/piyumal/roberta_sinhala/Roberta_tokenizer_30000/vocab.json',
                            merges_file='/userdirs/piyumal/roberta_sinhala/Roberta_tokenizer_30000/merges.txt', max_len=512)
# tokenizer = RobertaTokenizer(vocab_file='/userdirs/piyumal/roberta_sinhala/Roberta_tokenizer_52000/vocab.json',
#                              merges_file='/userdirs/piyumal/roberta_sinhala/Roberta_tokenizer_52000/merges.txt', max_len=512)

# %%
from sklearn.model_selection import train_test_split
train_texts, val_texts, train_labels, val_labels  = train_test_split(comments, labels, test_size=0.2)

# %%
# val_texts

# %%
train_encodings = tokenizer(train_texts, max_length=512, padding="max_length", truncation=True)
val_encodings = tokenizer(val_texts,  max_length=512, padding="max_length", truncation=True)

# %%
# train_labels = val_labels.to_list()
# val_labels = val_labels.to_list()

# %%
import torch

class SinhalaDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = SinhalaDataset(train_encodings, train_labels)
val_dataset = SinhalaDataset(val_encodings, val_labels)

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=True)

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer, EvalPrediction
model = AutoModelForSequenceClassification.from_pretrained('/userdirs/piyumal/roberta_sinhala/Roberta_models_tokenizer_30000/6_layer_model_0_157', num_labels=9)
# model = AutoModelForSequenceClassification.from_pretrained('/userdirs/piyumal/roberta_sinhala/Roberta_models_tokenizer_52000_12_layer/12_layer_model_0_68', num_labels=9)
# Out:
# Some weights of the model checkpoint at /userdirs/piyumal/roberta_sinhala/Roberta_models_tokenizer_30000/6_layer_model_0_157 were not used when initializing RobertaForSequenceClassification: ['lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
from sklearn.metrics import f1_score, precision_score, recall_score
import numpy as np
from sklearn.metrics import classification_report

training_args = TrainingArguments(
    learning_rate=5e-6,#5e-5,1e-4
    num_train_epochs=10,
    #evaluation_strategy="epoch",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    logging_steps=200,
    output_dir="outputs",
    overwrite_output_dir=True,
    evaluation_strategy  ='epoch'
)

def compute_accuracy(p: EvalPrediction):
    preds = np.argmax(p.predictions, axis=1)
    f1 = f1_score(p.label_ids, preds, average='macro')
    precision = precision_score(p.label_ids, preds, average='macro')
    recall = recall_score(p.label_ids, preds, average='macro')
    
    return {"acc": (preds == p.label_ids).mean(), "precision":precision, "recall": recall, "f1":f1}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_accuracy,
    
)

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 19275
#   Num Epochs = 10
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 12050
#     <div>
#
#       <progress value='12050' max='12050' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12050/12050 55:03, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Acc</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.359600</td>
#       <td>1.322953</td>
#       <td>0.525005</td>
#       <td>0.528009</td>
#       <td>0.472880</td>
#       <td>0.438574</td>
#     </tr>
#     <tr>
#       <td>2</td>
# ...

# %%
out=trainer.predict(val_dataset)
# Out:
# ***** Running Prediction *****
#   Num examples = 4819
#   Batch size = 16
#     <div>
#
#       <progress value='302' max='302' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [302/302 00:24]
#     </div>

# %%
y_pred=np.array((np.argmax(((out.predictions)),axis=-1)))
print(classification_report(np.array(val_labels),np.array(y_pred),digits=9))
# Out:
#               precision    recall  f1-score   support
#
#            0  0.924836601 0.943333333 0.933993399       600
#            1  0.472222222 0.194842407 0.275862069       349
#            2  0.756388416 0.699212598 0.726677578       635
#            3  0.435146444 0.344370861 0.384473198       302
#            4  0.417704011 0.505862647 0.457575758       597
#            5  0.396072013 0.408094435 0.401993355       593
#            6  0.552238806 0.506849315 0.528571429       584
#            7  0.522900763 0.706185567 0.600877193       582
#            8  0.929432014 0.935875217 0.932642487       577
#
#     accuracy                      0.616932974      4819
#    macro avg  0.600771254 0.582736264 0.582518496      4819
# weighted avg  0.618133713 0.616932974 0.610564186      4819
